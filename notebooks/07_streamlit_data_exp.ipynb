# %%
import pandas as pd
import numpy as np
import os
import sys

sys.path.append('../')

from src.utilities.config_ import combined_data_path, scrape_data_path, predicted_data_path
import src.utilities.utils as utils

# %%
# read feather
df = utils.load(os.path.join(combined_data_path, 'combined_data.feather'))
df = df[df["label"] != "neutral"].reset_index(drop=True)
df
# Out:
#                                                  title        date  \
# 0    Bitcoin Q3 Fundamental Outlook – Short-Term Mu...  30-06-2024
# 1    US Dollar Q3 Fundamental Outlook: US Dollar to...  28-06-2024
# 2    ​​​FTSE 100, DAX 40 on a positive footing ahea...  28-06-2024
# 3    US Dollar Slips After US Durable Goods, Jobs D...  27-06-2024
# 4    Aussie CPI Surpasses Estimates, Fueling RBA Hi...  26-06-2024
# ..                                                 ...         ...
# 160  India's forex reserves rise by $816 million to...  28-06-2024
# 161  India's key infra sectors' growth slows to 6.3...  28-06-2024
# 162  Swiss central bank cuts interest rates for the...  20-06-2024
# 163  Rich countries plan to buy more gold despite r...  18-06-2024
# 164  Global central banks plan to increase dollar r...  04-06-2024
#
#                                                    url             category  \
# 0    https://www.dailyfx.com/news/bitcoin-q3-fundam...                forex
# 1    https://www.dailyfx.com/news/us-dollar-q3-fund...                forex
# 2    https://www.dailyfx.com/analysis/ftse-100-dax-...                forex
# 3    https://www.dailyfx.com/news/us-dollar-slips-a...                forex
# 4    https://www.dailyfx.com/news/aussie-cpi-surpas...                forex
# ..                                                 ...                  ...
# 160  https://economictimes.indiatimes.com//news/eco...              economy
# 161  https://economictimes.indiatimes.com//news/eco...              economy
# 162  ft.com/content/ffe50093-1b35-4fce-a0d1-b3ef79d...  Swiss National Bank
# 163  ft.com/content/578237db-be6e-4df7-a1bc-0e72e88...                 Gold
# 164  ft.com/content/1be234f2-c680-4ce9-beb7-d0d9a27...        Central banks
#
#         label          source
# 0    positive         dailyfx
# 1    negative         dailyfx
# 2    positive         dailyfx
# 3    negative         dailyfx
# 4    positive         dailyfx
# ..        ...             ...
# 160  positive       econtimes
# 161  positive       econtimes
# 162  positive  financialtimes
# 163  positive  financialtimes
# 164  positive  financialtimes
#
# [165 rows x 6 columns]

# %%
# filter based on source
dailyfx_df = df[df["source"] == "dailyfx"].reset_index(drop=True)
econtimes_df = df[df["source"] == "econtimes"].reset_index(drop=True)
financialtimes_df = df[df["source"] == "financialtimes"].reset_index(drop=True)

# %%
def get_sentiment_stats(df):
    # Get the total count of each sentiment label
    label_counts = df['label'].value_counts()

    # get total for each label 
    total_neutral = label_counts.get('neutral', 0)
    total_positive = label_counts.get('positive', 0)
    total_negative = label_counts.get('negative', 0)

    # return
    total_negative, total_neutral, total_positive

    try:
        score = (total_positive - total_negative) / (total_negative + total_positive + total_neutral)

    except ZeroDivisionError as e:
        score = 0

    print(score)
    return score

for j in range(1, 31):
    formatted_number = f"{j:02}"
    score = get_sentiment_stats(df[df["date"] == f"{formatted_number}-06-2024"])

    # if score < 0:
    #     print(score)
# Out:
# 1.0
# 0.0
# 1.0
# -0.14285714285714285
# 0.25
# 0.3333333333333333
# 0.5
# 0.6
# 1.0
# 0.0
# 1.0
# 0.0
# 0.0
# 1.0
# 1.0
# 1.0
# 1.0
# 0.6363636363636364
# 0.5555555555555556
# 0.45454545454545453
# 0.6363636363636364
# 1.0
# 1.0
# 0.7142857142857143
# 1.0
# 1.0
# 0.5
# 0.5
# 0
# 1.0

# %%
# Group by 'source' and 'label', then count the occurrences
label_counts = df.groupby(['source', 'label']).size().unstack(fill_value=0)

print(label_counts)
# Out:
# label           negative  neutral  positive
# source
# dailyfx                9       88        12
# econtimes             25      495       116
# financialtimes         0       29         3
